# %%
from lightningchart_trader import TAChart
import pandas as pd
import os
import requests
license_key_path = "Python-Trader_License_key.txt" 
# Load the license key and initializing Python trader
license_key = open(license_key_path).read()
api_key_path = "API-key.txt" 
# Load the license key 
api_key = open(api_key_path).read() 
filepath = 'data/project-9/'
company_names = []
# Get file names
csv_list = os.listdir(filepath)
print(csv_list)
# Trader instance initialization
trader = TAChart(license_key)
# Using Alphavantages ticker search api get the names of companies analyzed.
for stock in csv_list:
    stock_ticker = stock.replace('.csv','')
    api_url = f'https://www.alphavantage.co/query?function=SYMBOL_SEARCH&keywords={stock_ticker}&apikey={api_key}'
    request = requests.get(api_url).json()
    print(request)
    stock_name = request['bestMatches'][0]['2. name']
    company_names.append(stock_name)
# Out:
# ['crk.csv', 'FHB.csv', 'HBI.csv', 'K.csv', 'LOW.csv', 'NVT.csv', 'OMI.csv', 'ONEW.csv', 'TOPS.csv', 'UNTY.csv']
# {'bestMatches': [{'1. symbol': 'CRK', '2. name': 'Comstock Resources Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}, {'1. symbol': 'CRKM', '2. name': 'Crank Media Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8571'}, {'1. symbol': 'CRKHF', '2. name': 'Cartrack Holdings Ltd', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'CRKRX', '2. name': 'Columbia Adaptive Risk Allocation Fund R', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'CRKXX', '2. name': 'MFS U.S. GOVERNMENT CASH RESERVE FUND R4', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}]}
# {'bestMatches': [{'1. symbol': 'FHB', '2. name': 'First Hawaiian Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}, {'1. symbol': 'FHBC', '2. name': 'Fernhill Beverage Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8571'}, {'1. symbol': 'FHBBX', '2. name': 'Federated Hermes High Inc Bd Fd Inc USD Class B', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'FHBCX', '2. name': 'FIDELITY FREEDOM BLEND 2035 FUND FIDELITY ADVISOR FREEDOM BLEND 2035 FUND: CLASS M', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'FHBDX', '2. name': 'Fidelity Advisor Freedom Blend Income Fd USD Class Z - 6', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'FHBEX', '2. name': 'FIDELITY FREEDOM BLEND 2025 FUND CLASS K', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'FHBFX', '2. name': 'FIDELITY FREEDOM BLEND 2045 FUND FIDELITY ADVISOR FREEDOM BLEND 2045 FUND: CLASS Z', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'FHBRX', '2. name': 'FEDERATED HERMES SUSTAINABLE HIGH YIELD BOND FUND', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'FHBONX', '2. name': 'The First Trust Combined Series 493 Tax Exempt Municipal Income Trust Series 2', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.6667'}, {'1. symbol': 'FHBVNX', '2. name': 'FT Unit 8307 Technology Divid Ptf Ser 32 Monthly Cash', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.6667'}]}
# {'bestMatches': [{'1. symbol': 'HBI', '2. name': 'Hanesbrands Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}, {'1. symbol': 'HBIA', '2. name': 'Hills Bancorporation', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8571'}, {'1. symbol': 'HBIO', '2. name': 'Harvard Bioscience Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8571'}, {'1. symbol': 'HBI.FRK', '2. name': 'Harvard Bioscience Inc', '3. type': 'Equity', '4. region': 'Frankfurt', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.7500'}, {'1. symbol': 'HBIAX', '2. name': 'HSBC Strategic Income Fund Class A', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'HBIIX', '2. name': 'HSBC Strategic Income Fund Class I', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'HBIE.TRT', '2. name': 'Harvest Balanced Income & Growth Enhanced ETF Class A', '3. type': 'ETF', '4. region': 'Toronto', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-05', '8. currency': 'CAD', '9. matchScore': '0.6000'}, {'1. symbol': 'HBIG.TRT', '2. name': 'Harvest Balanced Income & Growth ETF Class A', '3. type': 'ETF', '4. region': 'Toronto', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-05', '8. currency': 'CAD', '9. matchScore': '0.6000'}, {'1. symbol': 'HBIL.TRT', '2. name': 'Hamilton U.S. T-Bill YIELD MAXIMIZER ETF CAD Hedged Units', '3. type': 'ETF', '4. region': 'Toronto', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-05', '8. currency': 'CAD', '9. matchScore': '0.6000'}, {'1. symbol': 'HBIL-U.TRT', '2. name': 'Hamilton U.S. T-Bill YIELD MAXIMIZER ETF USD Unhedged Units', '3. type': 'ETF', '4. region': 'Toronto', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-05', '8. currency': 'CAD', '9. matchScore': '0.5000'}]}
# {'bestMatches': [{'1. symbol': 'K', '2. name': 'Kellanova Company', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}, {'1. symbol': 'K.TRT', '2. name': 'Kinross Gold Corp', '3. type': 'Equity', '4. region': 'Toronto', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-05', '8. currency': 'CAD', '9. matchScore': '0.4000'}, {'1. symbol': 'K0I.FRK', '2. name': 'EDREAMS ODIGEO UNS.ADR/10', '3. type': 'Equity', '4. region': 'Frankfurt', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.3333'}, {'1. symbol': 'K13.FRK', '2. name': 'COMBINEDX AB', '3. type': 'Equity', '4. region': 'Frankfurt', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.3333'}, {'1. symbol': 'K1G.FRK', '2. name': 'GROUNDED PEOPLE APPAREL', '3. type': 'Equity', '4. region': 'Frankfurt', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.3333'}, {'1. symbol': 'K0MR.DEX', '2. name': 'L&G Gerd Kommer Multifactor Equity UCITS ETF USD Distributing EUR', '3. type': 'ETF', '4. region': 'XETRA', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.2500'}, {'1. symbol': 'K1EY34.SAO', '2. name': 'KeyCorp', '3. type': 'Equity', '4. region': 'Brazil/Sao Paolo', '5. marketOpen': '10:00', '6. marketClose': '17:30', '7. timezone': 'UTC-03', '8. currency': 'BRL', '9. matchScore': '0.2500'}, {'1. symbol': 'K1BF34.SAO', '2. name': 'KB Financial Group Inc.', '3. type': 'Equity', '4. region': 'Brazil/Sao Paolo', '5. marketOpen': '10:00', '6. marketClose': '17:30', '7. timezone': 'UTC-03', '8. currency': 'BRL', '9. matchScore': '0.2000'}, {'1. symbol': 'K1EL34.SAO', '2. name': 'Kellanova', '3. type': 'Equity', '4. region': 'Brazil/Sao Paolo', '5. marketOpen': '10:00', '6. marketClose': '17:30', '7. timezone': 'UTC-03', '8. currency': 'BRL', '9. matchScore': '0.2000'}, {'1. symbol': 'K1IM34.SAO', '2. name': 'Kimco Realty Corporation', '3. type': 'Equity', '4. region': 'Brazil/Sao Paolo', '5. marketOpen': '10:00', '6. marketClose': '17:30', '7. timezone': 'UTC-03', '8. currency': 'BRL', '9. matchScore': '0.2000'}]}
# {'bestMatches': [{'1. symbol': 'LOW', '2. name': 'Lowe`s Cos. Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}, {'1. symbol': 'LOWAX', '2. name': 'LADENBURG GROWTH & INCOME FUND CLASS A SHARES', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'LOWCX', '2. name': 'LADENBURG GROWTH & INCOME FUND CLASS C SHARES', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'LOWIX', '2. name': 'LADENBURG GROWTH & INCOME FUND CLASS I SHARES', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'LOWLD', '2. name': 'Lowell Farms Corp Sub Vtg Sh', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'LOWLF', '2. name': 'Lowell Farms Inc (Sub Voting)', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'LOWD.FRK', '2. name': 'BNP PARIBAS EASY - Low Carbon 300 World PAB UCITS ETF EUR Acc', '3. type': 'ETF', '4. region': 'Frankfurt', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.6667'}, {'1. symbol': 'LOWE.LON', '2. name': 'SSgA SPDR ETFs Europe II Public Limited Company - SPDR EURO STOXX Low Volatility UCITS ETF', '3. type': 'ETF', '4. region': 'United Kingdom', '5. marketOpen': '08:00', '6. marketClose': '16:30', '7. timezone': 'UTC+01', '8. currency': 'GBP', '9. matchScore': '0.6667'}, {'1. symbol': 'LOWD.DEX', '2. name': 'BNP PARIBAS EASY - Low Carbon 300 World PAB UCITS ETF EUR Acc', '3. type': 'ETF', '4. region': 'XETRA', '5. marketOpen': '08:00', '6. marketClose': '20:00', '7. timezone': 'UTC+02', '8. currency': 'EUR', '9. matchScore': '0.6000'}, {'1. symbol': 'LOWC34.SAO', '2. name': "Lowe's Companies Inc", '3. type': 'Equity', '4. region': 'Brazil/Sao Paolo', '5. marketOpen': '10:00', '6. marketClose': '17:30', '7. timezone': 'UTC-03', '8. currency': 'BRL', '9. matchScore': '0.5000'}]}
# {'bestMatches': [{'1. symbol': 'NVT', '2. name': 'nVent Electric plc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}, {'1. symbol': 'NVTP', '2. name': 'Novt Corp', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8571'}, {'1. symbol': 'NVTS', '2. name': 'Navitas Semiconductor Corp', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8571'}, {'1. symbol': 'NVTX', '2. name': 'Tradr 2X Long NVTS Daily ETF', '3. type': 'ETF', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8571'}, {'1. symbol': 'NVT.LON', '2. name': 'Northern Venture Trust', '3. type': 'Equity', '4. region': 'United Kingdom', '5. marketOpen': '08:00', '6. marketClose': '16:30', '7. timezone': 'UTC+01', '8. currency': 'GBX', '9. matchScore': '0.7500'}, {'1. symbol': 'NVT.TRV', '2. name': 'Nortec Minerals Corp', '3. type': 'Equity', '4. region': 'Toronto Venture', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-05', '8. currency': 'CAD', '9. matchScore': '0.7500'}, {'1. symbol': 'NVTQF', '2. name': 'Patterson Metals Corp - Class A', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'NVTRQ', '2. name': 'Nuvectra Corp', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'NVTZF', '2. name': 'Navitas Ltd Ord', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}]}
# {'bestMatches': [{'1. symbol': 'OMI', '2. name': 'Owens & Minor Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}, {'1. symbol': 'OMID', '2. name': 'OMID HLDGS Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.8571'}, {'1. symbol': 'OMI.LON', '2. name': 'Orosur Mining Inc', '3. type': 'Equity', '4. region': 'United Kingdom', '5. marketOpen': '08:00', '6. marketClose': '16:30', '7. timezone': 'UTC+01', '8. currency': 'GBX', '9. matchScore': '0.7500'}, {'1. symbol': 'OMI.TRV', '2. name': 'Orosur Mining Inc', '3. type': 'Equity', '4. region': 'Toronto Venture', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-05', '8. currency': 'CAD', '9. matchScore': '0.7500'}, {'1. symbol': 'OMIAX', '2. name': 'FEDERATED HERMES OHIO MUNICIPAL INCOME FUND CLASS A SHARES', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'OMIFX', '2. name': 'FEDERATED HERMES OHIO MUNICIPAL INCOME FUND CLASS F SHARES', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'OMIIX', '2. name': 'FEDERATED HERMES OHIO MUNICIPAL INCOME FUND INSTITUTIONAL SHARES', '3. type': 'Mutual Fund', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.7500'}, {'1. symbol': 'OMIP.LON', '2. name': 'One Media iP Group Plc', '3. type': 'Equity', '4. region': 'United Kingdom', '5. marketOpen': '08:00', '6. marketClose': '16:30', '7. timezone': 'UTC+01', '8. currency': 'GBX', '9. matchScore': '0.6667'}, {'1. symbol': 'OMMSF', '2. name': 'Omineca Mining and Metals Ltd', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.5000'}, {'1. symbol': 'OMINFRAL.BSE', '2. name': 'OM Infra Ltd', '3. type': 'Equity', '4. region': 'India/Bombay', '5. marketOpen': '09:15', '6. marketClose': '15:30', '7. timezone': 'UTC+5.5', '8. currency': 'INR', '9. matchScore': '0.4286'}]}
# {'bestMatches': [{'1. symbol': 'ONEW', '2. name': 'Onewater Marine Inc - Class A', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}]}
# {'bestMatches': [{'1. symbol': 'TOPS', '2. name': 'Top Ships Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}, {'1. symbol': 'TPSRF', '2. name': 'Topsports International Holdings Ltd', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '0.6667'}]}
# {'bestMatches': [{'1. symbol': 'UNTY', '2. name': 'Unity Bancorp Inc', '3. type': 'Equity', '4. region': 'United States', '5. marketOpen': '09:30', '6. marketClose': '16:00', '7. timezone': 'UTC-04', '8. currency': 'USD', '9. matchScore': '1.0000'}]}

# %% [markdown]
# Index used to access individual files in the csv_list<br>
# Note the index value might vary if the files are in different order, compared to the example

# %%
file_index = 2
stock_dataframe = pd.read_csv(filepath + csv_list[file_index])
# Python trader requires the fields Open,Low,High,Close to function properly. The fields name are case sensitive.
# Add a volume indicator
trader.add_volume()
trader.change_time_range(3)
trader.set_color_theme('darkGold')
trader.set_data(stock_dataframe)
trader.set_chart_title(company_names[file_index])
trader.open()
# Out:
#         <iframe
#             width="100%"
#             height="600"
#             src="http://localhost:55115/?id=14817ccf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# Note the dashboard doesn't format very well on python notebooks. I recommend opening it in browser instead
# trader.open(method='browser')

# %%
# Create a dashboard with two columns and 5 rows. The row and column index determine the charts position wihtin the dashboard.
dashboard = trader.create_dashboard(5, 2)
row_index = 0
column_index = 0
use_adjusted = False
# Loop used to import data to the trader. 
for name, company in zip(company_names, csv_list):
    stock_dataframe = pd.read_csv(filepath + company)
    if use_adjusted:
        stock_dataframe = stock_dataframe.drop(columns= 'Close')
        stock_dataframe = stock_dataframe.rename(columns={'Adj Close': 'Close'})
    # Insert a chart to the dashboard and set the dataframe as the data source
    newchart = dashboard.add_chart('Line', row_index, column_index, title=name).set_data(stock_dataframe)
    newchart.add_volume()
    # Increment the index and column number where the chart should be positioned.
    if column_index == 1:
        column_index = 0
        row_index += 1
    elif column_index == 0:
        column_index += 1
    print(f'Loading {name}...')
trader.open()
#trader.open(method='browser')
# Out:
# Loading Comstock Resources Inc...
# Loading First Hawaiian Inc...
# Loading Hanesbrands Inc...
# Loading Kellanova Company...
# Loading Lowe`s Cos. Inc...
# Loading nVent Electric plc...
# Loading Owens & Minor Inc...
# Loading Onewater Marine Inc - Class A...
# Loading Top Ships Inc...
# Loading Unity Bancorp Inc...
#         <iframe
#             width="100%"
#             height="600"
#             src="http://localhost:55115/?id=14817ccf"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
